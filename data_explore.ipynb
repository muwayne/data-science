# %%
import pandas as pd
import numpy as np
from IPython.display import display
pd.set_option('display.max_columns', None)

# %%
dfloan = pd.read_csv('2012_to_2014_loans_data.csv')
# Out:
# D:\Work\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2723: DtypeWarning: Columns (3,4,5,7,8,9,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
dfloan.head(5)
# Out:
#    Agency_Code Applicant_Income_000  As_of_Year Census_Tract_Number  \
# 0            3                 0084        2012             0207.00
# 1            3                 0084        2012             9556.00
# 2            3                 0053        2012             9556.00
# 3            3                 0085        2012             0206.01
# 4            3                 0038        2012             0107.01
#
#   County_Code FFIEC_Median_Family_Income  Loan_Amount_000 MSA_MD  \
# 0         079                   00054900               94  16620
# 1         043                   00054900              133  16620
# 2         043                   00054900               70  16620
# 3         079                   00054900              102  16620
# 4         039                   00054900              112  16620
#
#   Number_of_Owner_Occupied_Units Respondent_ID  Sequence_Number  State_Code  \
# 0                       00001545    0000000384              390          54
# ...

# %%
dfinst = pd.read_csv('2012_to_2014_institutions_data.csv')

# %%
dfloan.first
# Out:
# <bound method NDFrame.first of          Agency_Code Applicant_Income_000  As_of_Year Census_Tract_Number  \
# 0                  3                 0084        2012             0207.00
# 1                  3                 0084        2012             9556.00
# 2                  3                 0053        2012             9556.00
# 3                  3                 0085        2012             0206.01
# 4                  3                 0038        2012             0107.01
# 5                  3                 0113        2012             0206.05
# 6                  3                 0091        2012             9555.00
# 7                  3                 0025        2012             0121.00
# 8                  3                 0111        2012             0019.02
# 9                  3                 0070        2012             0206.05
# 10                 3                 0048        2012             0206.04
# ...

# %%
dfloan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1321158 entries, 0 to 1321157
# Data columns (total 24 columns):
# Agency_Code                       1321158 non-null int64
# Applicant_Income_000              1321158 non-null object
# As_of_Year                        1321158 non-null int64
# Census_Tract_Number               1321158 non-null object
# County_Code                       1321158 non-null object
# FFIEC_Median_Family_Income        1321158 non-null object
# Loan_Amount_000                   1321158 non-null int64
# MSA_MD                            1321158 non-null object
# Number_of_Owner_Occupied_Units    1321158 non-null object
# Respondent_ID                     1321158 non-null object
# Sequence_Number                   1321158 non-null int64
# State_Code                        1321158 non-null int64
# Tract_to_MSA_MD_Income_Pct        1320258 non-null object
# MSA_MD_Description                1225941 non-null object
# ...

# %%
dfinst.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21655 entries, 0 to 21654
# Data columns (total 12 columns):
# As_of_Year             21655 non-null int64
# Respondent_ID          21655 non-null object
# Agency_Code            21655 non-null int64
# Respondent_Name_TS     21655 non-null object
# Respondent_City_TS     21655 non-null object
# Respondent_State_TS    21655 non-null object
# Respondent_ZIP_Code    21655 non-null object
# Parent_Name_TS         5458 non-null object
# Parent_City_TS         5455 non-null object
# Parent_State_TS        5486 non-null object
# Parent_ZIP_Code        5477 non-null object
# Assets_000_Panel       21655 non-null int64
# dtypes: int64(3), object(9)
# memory usage: 2.0+ MB

# %%
dfinst['Parent_Name_TS'].value_counts()
# Out:
# WELLS FARGO BANK, N.A.            70
# WINTRUST FINANCIAL CORPORATION    35
# ZIONS BANCORPORATION              23
# FULTON FINANCIAL CORPORATION      15
# HEARTLAND FINANCIAL USA, INC      15
# BREMER FINANCIAL CORPORATION      13
# COMMUNITY BANCSHARES              13
# CAPITOL BANCORP LIMITED           11
# SOUTH CENTRAL BANCSHARES OF KY    10
# INTERNATIONAL BANCSHARES CORP.     9
# FIFTH THIRD BANCORP                9
# UNIVERSITY BANK                    9
# M&T BANK CORPORATION               9
# SIMMONS FIRST NATIONAL CORP        9
# AMES NATIONAL CORPORATION          9
# FARMERS & MERCHANTS BANCORP        9
# FIRST NATIONAL BANK                8
# FIRST STATE BANK                   8
# TOWNEBANK                          8
# BB&T CORPORATION                   8
# MINNWEST CORPORATION               8
# PERSONS BANKING COMPANY            7
# PHH HOME LOANS, LLC                7
# 215 HOLDING COMPANY                7
# VALLEY VIEW BANCSHARES             7
# ...

# %%
dfinst['Respondent_Name_TS'].value_counts()
# Out:
# FIRST NATIONAL BANK               99
# FIRST STATE BANK                  71
# CITIZENS STATE BANK               48
# COMMUNITY BANK                    44
# CITIZENS BANK                     43
# FARMERS STATE BANK                38
# SECURITY STATE BANK               38
# FIRST COMMUNITY BANK              34
# PEOPLES BANK                      31
# FIRST BANK                        29
# COMMUNITY FIRST BANK              26
# HERITAGE BANK                     26
# CITIZENS NATIONAL BANK            25
# COMMUNITY NATIONAL BANK           25
# COOPERATIVA DE AHORRO Y CREDIT    22
# FARMERS & MERCHANTS BANK          21
# THE PEOPLES BANK                  21
# FIRST FEDERAL SAVINGS BANK        20
# ALLIANCE BANK                     19
# LIBERTY BANK                      19
# PINNACLE BANK                     18
# FIRST FEDERAL BANK                17
# CENTRAL BANK                      17
# UNITED BANK                       17
# CORNERSTONE BANK                  16
# ...

# %%
len(dfinst.groupby(['As_of_Year', 'Respondent_ID', 'Agency_Code']))
# Out:
# 21655

# %%
dfinst.loc[dfinst['Respondent_ID']=='0000003601'].dtype
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-02dbb23dd059> in <module>()
# ----> 1 dfinst.loc[dfinst['Respondent_ID']=='0000003601'].dtype
#
# NameError: name 'dfinst' is not defined

# %%
dfinst[dfinst['Parent_Name_TS'].isnull()].apply(pd.Series.nunique)
# Out:
# As_of_Year                 3
# Respondent_ID           6258
# Agency_Code                6
# Respondent_Name_TS      6948
# Respondent_City_TS      2800
# Respondent_State_TS       52
# Respondent_ZIP_Code     5445
# Parent_Name_TS             0
# Parent_City_TS             4
# Parent_State_TS           19
# Parent_ZIP_Code           15
# Assets_000_Panel       14198
# dtype: int64

# %%
dfinst[dfinst['Parent_Name_TS'].isnull()]['Parent_City_TS'].value_counts()
# Out:
# SPOKANE      2
# COLUMBIA     1
# SAN JUAN     1
# LAFAYETTE    1
# Name: Parent_City_TS, dtype: int64

# %%
dfinst.apply(pd.Series.nunique)
# Out:
# As_of_Year                 3
# Respondent_ID           7914
# Agency_Code                6
# Respondent_Name_TS      8740
# Respondent_City_TS      3281
# Respondent_State_TS       52
# Respondent_ZIP_Code     6615
# Parent_Name_TS          2945
# Parent_City_TS          1447
# Parent_State_TS           52
# Parent_ZIP_Code         2222
# Assets_000_Panel       18942
# dtype: int64

# %%
pnames = dfinst[dfinst['Parent_Name_TS'].notnull()]['Parent_Name_TS'].unique()
print(len(pnames))
rnames = dfinst['Respondent_Name_TS'].unique()
print(len(rnames))
allnames = np.concatenate((pnames,rnames), axis=0)
print(len(allnames))
uniall = np.unique(allnames)
print(len(uniall))
for name in np.sort(uniall)[1:50]:
  print(name)
# Out:
# 2945
# 8740
# 11685
# 11077
# 1-800-EAST/WEST MORTGAGE CO.
# 1150 PURCHASE STREET
# 1199 SEIU FEDERAL CREDIT UNION
# 121 FINANCIAL CREDIT UNION
# 167TH TFR FEDERAL CREDIT UNION
# 1867 WESTERN FINANCIAL CORP.
# 1889 BANCORP MHC
# 1ST 2ND MORTGAGE CO. OF NJ INC
# 1ST ADVANTAGE BANCSHARES
# 1ST ADVANTAGE BANK
# 1ST ADVANTAGE FCU
# 1ST ADVANTAGE FEDERAL CREDIT
# 1ST ADVANTAGE MORTGAGE
# 1ST ALLIANCE LENDING, LLC
# 1ST BANK
# 1ST BANK OF SEA ISLE CITY
# 1ST BANK YUMA
# 1ST BANK, N.A.
# 1ST CAMERON STATE BANK
# 1ST CAPITAL BANK
# 1ST CENTURY BANCSHARES
# 1ST CENTURY BANK N.A.
# 1ST CENTURY BANK, N.A.
# 1ST COLONIAL BANCORP INC
# 1ST COLONIAL COMMUNITY  BANK
# 1ST COLONIAL COMMUNITY BANK
# 1ST COMMUNITY BANK
# 1ST COMMUNITY CREDIT UNION
# 1ST COMMUNITY FCU
# 1ST CONSTITUTION BANCORP
# 1ST CONSTITUTION BANK
# 1ST CREDIT UNION OF GAINESVILL
# 1ST ENTERPRISE BANK
# 1ST EQUITY BANK
# 1ST EQUITY BANK NORTHWEST
# 1ST FARMERS &  MERCHANTS BANK
# 1ST FARMERS & MERCHANTS BANK
# ...

# %%
[1,2,3][1:2]
# Out:
# [2]

# %%
len(dfinst[dfinst['Respondent_Name_TS'].notnull()]['Respondent_Name_TS'].unique())
# Out:
# 8740

# %%
print(np.unique(np.concatenate((dfinst[dfinst['Parent_Name_TS'].notnull()]['Parent_Name_TS'].unique(), dfinst[dfinst['Respondent_Name_TS'].notnull()]['Respondent_Name_TS'].unique()), axis=0))[1..10])
# Out:
#   File "<ipython-input-108-1218fb0c615a>", line 1
#     print(np.unique(np.concatenate((dfinst[dfinst['Parent_Name_TS'].notnull()]['Parent_Name_TS'].unique(), dfinst[dfinst['Respondent_Name_TS'].notnull()]['Respondent_Name_TS'].unique()), axis=0))[1..10])
#                                                                                                                                                                                                         ^
# SyntaxError: invalid syntax

# %%
np.unique([1,2,3,3])
# Out:
# array([1, 2, 3])

# %%
dfloan.head(1)
# Out:
#    Agency_Code Applicant_Income_000  As_of_Year Census_Tract_Number  \
# 0            3                 0084        2012             0207.00
#
#   County_Code FFIEC_Median_Family_Income  Loan_Amount_000 MSA_MD  \
# 0         079                   00054900               94  16620
#
#   Number_of_Owner_Occupied_Units Respondent_ID  Sequence_Number  State_Code  \
# 0                       00001545    0000000384              390          54
#
#   Tract_to_MSA_MD_Income_Pct MSA_MD_Description Loan_Purpose_Description  \
# 0                     093.07     CHARLESTON, WV                Refinance
#
#   Agency_Code_Description Lien_Status_Description Loan_Type_Description State  \
# 0                    FDIC              First Lien          Conventional    WV
#
#   County_Name  Conforming_Limit_000 Conventional_Status Conforming_Status  \
# 0      PUTNAM                 417.0        Conventional        Conforming
#
#   Conventional_Conforming_Flag
# 0                            Y

# %%
dfloan['Loan_Amount_000'].value_counts()
# Out:
# 417      22969
# 200       9689
# 150       7737
# 300       7343
# 250       7314
# 100       7194
# 180       6371
# 626       6342
# 160       6337
# 400       6062
# 240       5931
# 140       5672
# 260       5565
# 220       5497
# 175       5419
# 190       5417
# 280       5398
# 170       5350
# 225       5303
# 230       5190
# 120       5141
# 130       5024
# 125       4947
# 245       4883
# 255       4808
# 165       4761
# 270       4758
# 135       4755
# 172       4710
# 210       4708
#          ...
# 13857        1
# 25130        1
# 1555         1
# 1572         1
# 91704        1
# 38407        1
# 1557         1
# 11795        1
# 59914        1
# 18974        1
# 1559         1
# 14878        1
# 35339        1
# 22032        1
# 26134        1
# 16915        1
# 12826        1
# 86582        1
# 32273        1
# 11802        1
# 40499        1
# 29231        1
# 1569         1
# 16938        1
# 39473        1
# 21033        1
# 9767         1
# ...

# %%
dfloan['Respondent_ID'].describe()
# Out:
# count        1321158
# unique          1683
# top       0000451965
# freq          119016
# Name: Respondent_ID, dtype: object
